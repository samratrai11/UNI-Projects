# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel("gdp per capita.xls")
df
# Out:
#                      Data Source World Development Indicators  \
# 0              Last Updated Date          2023-06-29 00:00:00
# 1                            NaN                          NaN
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 0                                 NaN                NaN         NaN
# 1                                 NaN                NaN         NaN
# ...

# %%
index_list = list(range(0,2))
df.drop(df.index[index_list], inplace =True)
df
# Out:
#                      Data Source World Development Indicators  \
# 2                   Country Name                 Country Code
# 3                          Aruba                          ABW
# 4    Africa Eastern and Southern                          AFE
# 5                    Afghanistan                          AFG
# 6     Africa Western and Central                          AFW
# ..                           ...                          ...
# 264                       Kosovo                          XKX
# 265                  Yemen, Rep.                          YEM
# 266                 South Africa                          ZAF
# 267                       Zambia                          ZMB
# 268                     Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 3    GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# ...

# %%
index_list = list(range(1,14))
df.drop(df.index[index_list], inplace =True)
df
# Out:
#       Data Source World Development Indicators  \
# 2    Country Name                 Country Code
# 16      Australia                          AUS
# 17        Austria                          AUT
# 18     Azerbaijan                          AZE
# 19        Burundi                          BDI
# ..            ...                          ...
# 264        Kosovo                          XKX
# 265   Yemen, Rep.                          YEM
# 266  South Africa                          ZAF
# 267        Zambia                          ZMB
# 268      Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 16   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 17   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 18   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# ...

# %%
index_list = list(range(2,69))
df.drop(df.index[index_list],inplace=True)
df
# Out:
#         Data Source World Development Indicators  \
# 2      Country Name                 Country Code
# 16        Australia                          AUS
# 84   United Kingdom                          GBR
# 85          Georgia                          GEO
# 86            Ghana                          GHA
# ..              ...                          ...
# 264          Kosovo                          XKX
# 265     Yemen, Rep.                          YEM
# 266    South Africa                          ZAF
# 267          Zambia                          ZMB
# 268        Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 16   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 84   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 85   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# ...

# %%
index_list = list(range(3,99))
df.drop(df.index[index_list], inplace =True)
df
# Out:
#         Data Source World Development Indicators  \
# 2      Country Name                 Country Code
# 16        Australia                          AUS
# 84   United Kingdom                          GBR
# 181           Nepal                          NPL
# 182           Nauru                          NRU
# ..              ...                          ...
# 264          Kosovo                          XKX
# 265     Yemen, Rep.                          YEM
# 266    South Africa                          ZAF
# 267          Zambia                          ZMB
# 268        Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 16   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 84   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 181  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# ...

# %%
index_list = list(range(4,12))
df.drop(df.index[index_list], inplace =True)
df
# Out:
#         Data Source World Development Indicators  \
# 2      Country Name                 Country Code
# 16        Australia                          AUS
# 84   United Kingdom                          GBR
# 181           Nepal                          NPL
# 190     Philippines                          PHL
# ..              ...                          ...
# 264          Kosovo                          XKX
# 265     Yemen, Rep.                          YEM
# 266    South Africa                          ZAF
# 267          Zambia                          ZMB
# 268        Zimbabwe                          ZWE
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 16   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 84   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 181  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# ...

# %%
index_list = list(range(5,83))
df.drop(df.index[index_list], inplace =True)
df
# Out:
#         Data Source World Development Indicators  \
# 2      Country Name                 Country Code
# 16        Australia                          AUS
# 84   United Kingdom                          GBR
# 181           Nepal                          NPL
# 190     Philippines                          PHL
#
#                            Unnamed: 2         Unnamed: 3  Unnamed: 4  \
# 2                      Indicator Name     Indicator Code      1960.0
# 16   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 84   GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 181  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
# 190  GDP per capita growth (annual %)  NY.GDP.PCAP.KD.ZG         NaN
#
#       Unnamed: 5   Unnamed: 6   Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  \
# 2    1961.000000  1962.000000  1963.000000  1964.000000  1965.000000  ...
# 16      0.463671    -1.147700     4.198486     4.901197     3.923740  ...
# ...

# %%
header_row = 0
df.columns = df.iloc[header_row]
df
# Out:
# 2      Country Name  Country Code                    Indicator Name  \
# 2      Country Name  Country Code                    Indicator Name
# 16        Australia           AUS  GDP per capita growth (annual %)
# 84   United Kingdom           GBR  GDP per capita growth (annual %)
# 181           Nepal           NPL  GDP per capita growth (annual %)
# 190     Philippines           PHL  GDP per capita growth (annual %)
#
# 2       Indicator Code  1960.0       1961.0       1962.0       1963.0  \
# 2       Indicator Code  1960.0  1961.000000  1962.000000  1963.000000
# 16   NY.GDP.PCAP.KD.ZG     NaN     0.463671    -1.147700     4.198486
# 84   NY.GDP.PCAP.KD.ZG     NaN     1.899262     0.248519     4.092469
# 181  NY.GDP.PCAP.KD.ZG     NaN    -0.030599    -0.071562    -0.108267
# 190  NY.GDP.PCAP.KD.ZG     NaN     2.613696     1.916292     4.059426
#
# 2         1964.0       1965.0  ...       2013.0       2014.0       2015.0  \
# ...

# %%
df.drop([2],inplace=True)
df
# Out:
# 2      Country Name Country Code                    Indicator Name  \
# 16        Australia          AUS  GDP per capita growth (annual %)
# 84   United Kingdom          GBR  GDP per capita growth (annual %)
# 181           Nepal          NPL  GDP per capita growth (annual %)
# 190     Philippines          PHL  GDP per capita growth (annual %)
#
# 2       Indicator Code  1960.0    1961.0    1962.0    1963.0    1964.0  \
# 16   NY.GDP.PCAP.KD.ZG     NaN  0.463671 -1.147700  4.198486  4.901197
# 84   NY.GDP.PCAP.KD.ZG     NaN  1.899262  0.248519  4.092469  4.849645
# 181  NY.GDP.PCAP.KD.ZG     NaN -0.030599 -0.071562 -0.108267  5.381354
# 190  NY.GDP.PCAP.KD.ZG     NaN  2.613696  1.916292  4.059426  0.574464
#
# 2      1965.0  ...    2013.0    2014.0    2015.0    2016.0    2017.0  \
# 16   3.923740  ...  0.828326  1.060337  0.693066  1.138424  0.604963
# 84   1.488048  ...  1.140213  2.442466  1.584979  1.393849  1.749954
# ...

# %%
df=df.reset_index()
df
# Out:
# 2  index    Country Name Country Code                    Indicator Name  \
# 0     16       Australia          AUS  GDP per capita growth (annual %)
# 1     84  United Kingdom          GBR  GDP per capita growth (annual %)
# 2    181           Nepal          NPL  GDP per capita growth (annual %)
# 3    190     Philippines          PHL  GDP per capita growth (annual %)
#
# 2     Indicator Code  1960.0    1961.0    1962.0    1963.0    1964.0  ...  \
# 0  NY.GDP.PCAP.KD.ZG     NaN  0.463671 -1.147700  4.198486  4.901197  ...
# 1  NY.GDP.PCAP.KD.ZG     NaN  1.899262  0.248519  4.092469  4.849645  ...
# 2  NY.GDP.PCAP.KD.ZG     NaN -0.030599 -0.071562 -0.108267  5.381354  ...
# 3  NY.GDP.PCAP.KD.ZG     NaN  2.613696  1.916292  4.059426  0.574464  ...
#
# 2    2013.0    2014.0    2015.0    2016.0    2017.0    2018.0    2019.0  \
# 0  0.828326  1.060337  0.693066  1.138424  0.604963  1.348283  0.665151
# 1  1.140213  2.442466  1.584979  1.393849  1.749954  1.090624  1.032741
# ...

# %%
df.drop([1960.0],inplace=True, axis=1)
df
# Out:
# 2  index    Country Name Country Code                    Indicator Name  \
# 0     16       Australia          AUS  GDP per capita growth (annual %)
# 1     84  United Kingdom          GBR  GDP per capita growth (annual %)
# 2    181           Nepal          NPL  GDP per capita growth (annual %)
# 3    190     Philippines          PHL  GDP per capita growth (annual %)
#
# 2     Indicator Code    1961.0    1962.0    1963.0    1964.0    1965.0  ...  \
# 0  NY.GDP.PCAP.KD.ZG  0.463671 -1.147700  4.198486  4.901197  3.923740  ...
# 1  NY.GDP.PCAP.KD.ZG  1.899262  0.248519  4.092469  4.849645  1.488048  ...
# 2  NY.GDP.PCAP.KD.ZG -0.030599 -0.071562 -0.108267  5.381354 -3.227262  ...
# 3  NY.GDP.PCAP.KD.ZG  2.613696  1.916292  4.059426  0.574464  2.490604  ...
#
# 2    2013.0    2014.0    2015.0    2016.0    2017.0    2018.0    2019.0  \
# 0  0.828326  1.060337  0.693066  1.138424  0.604963  1.348283  0.665151
# 1  1.140213  2.442466  1.584979  1.393849  1.749954  1.090624  1.032741
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  
    display(df)
# Out:
# 2  index    Country Name Country Code                    Indicator Name  \
# 0     16       Australia          AUS  GDP per capita growth (annual %)
# 1     84  United Kingdom          GBR  GDP per capita growth (annual %)
# 2    181           Nepal          NPL  GDP per capita growth (annual %)
# 3    190     Philippines          PHL  GDP per capita growth (annual %)
#
# 2     Indicator Code    1961.0    1962.0    1963.0    1964.0    1965.0  \
# 0  NY.GDP.PCAP.KD.ZG  0.463671 -1.147700  4.198486  4.901197  3.923740
# 1  NY.GDP.PCAP.KD.ZG  1.899262  0.248519  4.092469  4.849645  1.488048
# 2  NY.GDP.PCAP.KD.ZG -0.030599 -0.071562 -0.108267  5.381354 -3.227262
# 3  NY.GDP.PCAP.KD.ZG  2.613696  1.916292  4.059426  0.574464  2.490604
#
# 2    1966.0    1967.0    1968.0    1969.0    1970.0    1971.0    1972.0  \
# 0  0.068020  4.971516  3.256267  4.828380  5.085013  0.544150  2.017709
# 1  1.014665  2.234412  4.929077  1.501173  6.255522  3.073314  3.968556
# ...
