# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook


df=pd.read_excel('total greenhouse gas emission all.xlsx')
   
# plotting three histograms on the same axis
plt.hist(df['Australia'],bins = 5, alpha = 0.5, 
         color = 'green',edgecolor='k')
plt.hist(df['United Kingdom'],bins = 5, alpha = 1,
         color = 'blue',edgecolor='k')
plt.hist(df['Nepal'],bins = 30, alpha = 0.5,
         color = 'silver',edgecolor='k')
plt.hist(df['Philippines'],bins = 30, alpha = 0.5, 
         color = 'yellow',edgecolor='k')


plt.title("Total greenhouse gas emissions (kt of CO2 equivalent)")
plt.legend(['Australia','United Kingdom','Nepal','Philippines'])
plt.xlabel('Greenhouse gas emission value from 1960-2022')
plt.ylabel('Total Number of same greenhouse emission value occuring from 1960-2022')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook


df=pd.read_excel('total greenhouse gas emission all.xlsx')
   
# plotting three histograms on the same axis
plt.hist(df['Australia'],bins = 5, alpha = 0.5, 
         color = 'green',edgecolor='k')
plt.hist(df['United Kingdom'],bins = 5, alpha = 1,
         color = 'blue',edgecolor='k')



plt.title("Total greenhouse gas emissions (kt of CO2 equivalent)")
plt.legend(['Australia','United Kingdom'])
plt.xlabel('Greenhouse gas emission value from 1960-2022')
plt.ylabel('Total Number of same greenhouse emission value occuring from 1960-2022')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib notebook


df=pd.read_excel('total greenhouse gas emission all.xlsx')
   
# plotting three histograms on the same axis

plt.hist(df['Nepal'],bins = 30, alpha = 0.5,
         color = 'silver',edgecolor='k')
plt.hist(df['Philippines'],bins = 30, alpha = 0.5, 
         color = 'yellow',edgecolor='k')


plt.title("Total greenhouse gas emissions (kt of CO2 equivalent)")
plt.legend(['Nepal','Philippines'])
plt.xlabel('Greenhouse gas emission value from 1960-2022')
plt.ylabel('Total Number of same greenhouse emission value occuring from 1960-2022')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
