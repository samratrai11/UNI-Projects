# %% [markdown]
# # Loading the data into jupyter notebook.

# %%
import pandas as pd
df=pd.read_excel('minor roads emission 2010,13&16..xlsx')
df
# Out:
#         Grid_Id  Grid_Id_ExactCut Location_ExactCut Borough_ExactCut  Year  \
# 0          5910                 1            NonGLA           NonGLA  2010
# 1          5911                 2            NonGLA           NonGLA  2010
# 2          5912                 3            NonGLA           NonGLA  2010
# 3          5915                 4            NonGLA           NonGLA  2010
# 4          5916                 5            NonGLA           NonGLA  2010
# ...         ...               ...               ...              ...   ...
# 100645    10059              3351             Inner        Southwark  2016
# 100646    10059              3352           Central        Southwark  2016
# 100647     9714              3353           Central           Camden  2016
# 100648     9716              3354           Central        Islington  2016
# 100649     9716              3355           Central             City  2016
#
# ...

# %% [markdown]
# # Dropping columns which are not essential.

# %%
df.drop(columns=['Grid_Id','Grid_Id_ExactCut'],axis=1 ,inplace=True)
df
# Out:
#        Location_ExactCut Borough_ExactCut  Year  Pollutant Emissions  \
# 0                 NonGLA           NonGLA  2010        CO2       DFT
# 1                 NonGLA           NonGLA  2010        CO2       DFT
# 2                 NonGLA           NonGLA  2010        CO2       DFT
# 3                 NonGLA           NonGLA  2010        CO2       DFT
# 4                 NonGLA           NonGLA  2010        CO2       DFT
# ...                  ...              ...   ...        ...       ...
# 100645             Inner        Southwark  2016  PM25_Tyre    COPERT
# 100646           Central        Southwark  2016  PM25_Tyre    COPERT
# 100647           Central           Camden  2016  PM25_Tyre    COPERT
# 100648           Central        Islington  2016  PM25_Tyre    COPERT
# 100649           Central             City  2016  PM25_Tyre    COPERT
#
#        Emissions Unit  Motorcycle      Taxi  Petrol Car  Diesel Car  \
# 0          tonne/year    0.789607  0.728706   63.290727   28.659199
# ...

# %% [markdown]
# # Renaming inccorect column name.

# %%
df=df.rename(columns={'Total': 'Total PM 2.5 Emission'})
df
# Out:
#        Location_ExactCut Borough_ExactCut  Year  Pollutant Emissions  \
# 0                 NonGLA           NonGLA  2010        CO2       DFT
# 1                 NonGLA           NonGLA  2010        CO2       DFT
# 2                 NonGLA           NonGLA  2010        CO2       DFT
# 3                 NonGLA           NonGLA  2010        CO2       DFT
# 4                 NonGLA           NonGLA  2010        CO2       DFT
# ...                  ...              ...   ...        ...       ...
# 100645             Inner        Southwark  2016  PM25_Tyre    COPERT
# 100646           Central        Southwark  2016  PM25_Tyre    COPERT
# 100647           Central           Camden  2016  PM25_Tyre    COPERT
# 100648           Central        Islington  2016  PM25_Tyre    COPERT
# 100649           Central             City  2016  PM25_Tyre    COPERT
#
#        Emissions Unit  Motorcycle      Taxi  Petrol Car  Diesel Car  \
# 0          tonne/year    0.789607  0.728706   63.290727   28.659199
# ...

# %%
df.columns
# Out:
# Index(['Location_ExactCut', 'Borough_ExactCut', 'Year', 'Pollutant',
#        'Emissions', 'Emissions Unit', 'Motorcycle', 'Taxi', 'Petrol Car',
#        'Diesel Car', 'Electric Car', 'Petrol LGV', 'Diesel LGV',
#        'Electric LGV', 'TfL Bus', 'Non-TfL Bus and Coach', 'Rigid HGV',
#        'Artic HGV', 'Total PM 2.5 Emission'],
#       dtype='object')

# %%
data_with_index = df.set_index("Pollutant")
data_with_index.head()
# Out:
#           Location_ExactCut Borough_ExactCut  Year Emissions Emissions Unit  \
# Pollutant
# CO2                  NonGLA           NonGLA  2010       DFT     tonne/year
# CO2                  NonGLA           NonGLA  2010       DFT     tonne/year
# CO2                  NonGLA           NonGLA  2010       DFT     tonne/year
# CO2                  NonGLA           NonGLA  2010       DFT     tonne/year
# CO2                  NonGLA           NonGLA  2010       DFT     tonne/year
#
#            Motorcycle      Taxi  Petrol Car  Diesel Car  Electric Car  \
# Pollutant
# CO2          0.789607  0.728706   63.290727   28.659199           0.0
# CO2          0.518391  0.478272   41.554182   18.816494           0.0
# CO2          0.795632  0.734195   63.784549   28.882810           0.0
# CO2          0.787536  0.726727   63.081901   28.564638           0.0
# CO2          0.710495  0.655763   56.956611   25.790995           0.0
#
#            Petrol LGV  Diesel LGV  Electric LGV   TfL Bus  \
# ...

# %%
data_with_index = data_with_index.drop(["CO2", "PM10_Tyre", "NOx","PM10_Brake","PM10_Exhaust","PM10_Resusp","PM25_Resusp"])
data_with_index
# Out:
#            Location_ExactCut Borough_ExactCut  Year Emissions Emissions Unit  \
# Pollutant
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# ...                      ...              ...   ...       ...            ...
# PM25_Tyre              Inner        Southwark  2016    COPERT     tonne/year
# PM25_Tyre            Central        Southwark  2016    COPERT     tonne/year
# PM25_Tyre            Central           Camden  2016    COPERT     tonne/year
# PM25_Tyre            Central        Islington  2016    COPERT     tonne/year
# PM25_Tyre            Central             City  2016    COPERT     tonne/year
#
# ...

# %%
new_df=data_with_index

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 30195 entries, PM25_Brake to PM25_Tyre
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Location_ExactCut      30195 non-null  object
#  1   Borough_ExactCut       30195 non-null  object
#  2   Year                   30195 non-null  int64
#  3   Emissions              30195 non-null  object
#  4   Emissions Unit         30195 non-null  object
#  5   Motorcycle             30195 non-null  float64
#  6   Taxi                   30195 non-null  float64
#  7   Petrol Car             30195 non-null  float64
#  8   Diesel Car             30195 non-null  float64
#  9   Electric Car           30195 non-null  float64
#  10  Petrol LGV             30195 non-null  float64
#  11  Diesel LGV             30195 non-null  float64
#  12  Electric LGV           30195 non-null  float64
#  13  TfL Bus                30195 non-null  float64
# ...

# %%
new_df.columns
# Out:
# Index(['Location_ExactCut', 'Borough_ExactCut', 'Year', 'Emissions',
#        'Emissions Unit', 'Motorcycle', 'Taxi', 'Petrol Car', 'Diesel Car',
#        'Electric Car', 'Petrol LGV', 'Diesel LGV', 'Electric LGV', 'TfL Bus',
#        'Non-TfL Bus and Coach', 'Rigid HGV', 'Artic HGV',
#        'Total PM 2.5 Emission'],
#       dtype='object')

# %%
#sums up total null values of columns
new_df.isna().sum()
# Out:
# Location_ExactCut        0
# Borough_ExactCut         0
# Year                     0
# Emissions                0
# Emissions Unit           0
# Motorcycle               0
# Taxi                     0
# Petrol Car               0
# Diesel Car               0
# Electric Car             0
# Petrol LGV               0
# Diesel LGV               0
# Electric LGV             0
# TfL Bus                  0
# Non-TfL Bus and Coach    0
# Rigid HGV                0
# Artic HGV                0
# Total PM 2.5 Emission    0
# dtype: int64

# %%
new_df.head()
# Out:
#            Location_ExactCut Borough_ExactCut  Year Emissions Emissions Unit  \
# Pollutant
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
# PM25_Brake            NonGLA           NonGLA  2010    COPERT     tonne/year
#
#             Motorcycle      Taxi  Petrol Car  Diesel Car  Electric Car  \
# Pollutant
# PM25_Brake    0.000064  0.000059    0.005894    0.002905           0.0
# PM25_Brake    0.000042  0.000039    0.003870    0.001907           0.0
# PM25_Brake    0.000065  0.000059    0.005940    0.002928           0.0
# PM25_Brake    0.000064  0.000059    0.005875    0.002896           0.0
# PM25_Brake    0.000058  0.000053    0.005305    0.002614           0.0
#
# ...

# %%
new_df.tail()
# Out:
#           Location_ExactCut Borough_ExactCut  Year Emissions Emissions Unit  \
# Pollutant
# PM25_Tyre             Inner        Southwark  2016    COPERT     tonne/year
# PM25_Tyre           Central        Southwark  2016    COPERT     tonne/year
# PM25_Tyre           Central           Camden  2016    COPERT     tonne/year
# PM25_Tyre           Central        Islington  2016    COPERT     tonne/year
# PM25_Tyre           Central             City  2016    COPERT     tonne/year
#
#            Motorcycle      Taxi  Petrol Car  Diesel Car  Electric Car  \
# Pollutant
# PM25_Tyre    0.000000  0.000000    0.000000    0.000000      0.000000
# PM25_Tyre    0.000507  0.002053    0.004595    0.003905      0.000043
# PM25_Tyre    0.000745  0.002983    0.006754    0.005739      0.000064
# PM25_Tyre    0.000051  0.000200    0.000461    0.000392      0.000004
# PM25_Tyre    0.000623  0.002459    0.005653    0.004804      0.000054
#
#            Petrol LGV  Diesel LGV  Electric LGV   TfL Bus  \
# ...

# %%
new_df.describe()
# Out:
#               Year    Motorcycle          Taxi    Petrol Car    Diesel Car  \
# count  30195.00000  30195.000000  30195.000000  30195.000000  30195.000000
# mean    2013.00000      0.000198      0.000350      0.006850      0.006656
# std        2.44953      0.000312      0.001132      0.009498      0.007048
# min     2010.00000      0.000000      0.000000      0.000000      0.000000
# 25%     2010.00000      0.000024      0.000026      0.000641      0.001120
# 50%     2013.00000      0.000092      0.000105      0.002628      0.004194
# 75%     2016.00000      0.000265      0.000315      0.009419      0.009964
# max     2016.00000      0.006475      0.036213      0.076354      0.051548
#
#        Electric Car    Petrol LGV    Diesel LGV  Electric LGV       TfL Bus  \
# count  30195.000000  30195.000000  30195.000000  30195.000000  3.019500e+04
# mean       0.000007      0.000050      0.003353      0.000002  6.728246e-04
# ...
